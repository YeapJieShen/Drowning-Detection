# %% [markdown]
# ##### YOLO Annotation Format
# - class, x_center, y_center, width, height
# - class: {0, 1, 2 : swimming, tread water, drowning}
#
# ### YOLO Model for Human Detection
# Original Training Images -> ROIs -> Training
#
# We need these steps:
# 1. Human Detection/Segmentation, seperation of ROIs from frames (With YOLO/YOLO-obb)
# 2. Human Tracking (With SORT)
#
# This implementation :
# - YOLO11s + DeepSORT
# - YOLO model training in final_trainyolomodel.ipynb and results stored in human_detection folder
# - Final yolo model saved in models folder as human_detection_yolo11s.pt
# - This notebook runs the main.py file in the human_detection_tracker directory
# - The main.py file depends on tracker.py which depends on -> deep_sort folder + model_data ; src:GitHub

# %%
import os
os.chdir(r"C:\Users\jrom\DataspellProjects\Drowning-Detection")

# %%
# %run models/human_detection_tracker/main.py
# Out:
# Video Path: models\human_detection_tracker\test_videos\manyswimmers.mp4
#
# 0: 384x640 18 humans, 29.3ms
# Speed: 2.9ms preprocess, 29.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 humans, 20.1ms
# Speed: 2.2ms preprocess, 20.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 humans, 19.6ms
# Speed: 2.5ms preprocess, 19.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 humans, 20.8ms
# Speed: 1.6ms preprocess, 20.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 humans, 21.6ms
# Speed: 2.1ms preprocess, 21.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 humans, 19.8ms
# Speed: 2.2ms preprocess, 19.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 humans, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
